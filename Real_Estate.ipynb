# %% [markdown]
# <a href="https://colab.research.google.com/github/milosavljeviciva/domaci/blob/main/Real_Estate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Real estate.csv")
data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
#zavisnost cene kuce(po jedinici povrsine) od datuma transakcije
sns.scatterplot(data, x=data['X1 transaction date'], y=data['Y house price of unit area'])
plt.show()
#zavisnost cene kuce(po jedinici povrsine) od starosti kuce
sns.scatterplot(data, x=data['X2 house age'], y=data['Y house price of unit area'])
plt.show()
#zavisnost cene kuce(po jedinici povrsine) od udaljenosti od metroa
sns.scatterplot(data, x=data['X3 distance to the nearest MRT station'], y=data['Y house price of unit area'])
plt.show()
#zavisnost cene kuce(po jedinici povrsine) od broja prodavnica
sns.scatterplot(data, x=data['X4 number of convenience stores'], y=data['Y house price of unit area'])
plt.show()
#zavisnost cene kuce(po jedinici povrsine) od latitude
sns.scatterplot(data, x=data['X5 latitude'], y=data['Y house price of unit area'])
plt.show()
#zavisnost cene kuce(po jedinici povrsine) od longitude
sns.scatterplot(data, x=data['X6 longitude'], y=data['Y house price of unit area'])
plt.show()

# %%
cor = data.corr()
sns.heatmap(cor, annot=True, cmap="vlag",center=0)
# Out:
# <Axes: >
